# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_gharbazars.csv')

# %%
df.shape
# Out:
# (615, 18)

# %%
df.head(10)
# Out:
#                                                price        LAND AREA  \
# 0         Rs. 40,000 (Negotiable)\n(Forty thousand )          0-4-0-0
# 1     Rs. 32,00,000 (Negotiable)\n(32 lakh per aana)          0-4-0-0
# 2                          Rs. 7,00,000 (Negotiable)  999 SQUARE FEET
# 3  Rs. 2,30,00,000 (Negotiable)\n(Two crore thirt...          0-4-2-2
# 4                         Rs. 28,00,000 (Negotiable)          0-4-0-0
# 5  Rs. 1,25,000 / month (Negotiable)\n(One lakh t...         0-10-0-0
# 6  Rs. 3,40,00,000 (Negotiable)\n(Three crore for...          0-3-2-0
# 7  Rs. 5,35,00,000 (Negotiable)\n(Five crore thir...          0-7-1-0
# 8            Rs. 7,00,00,000 (Negotiable)\n(7 crore)          0-8-0-0
# 9  Rs. 6,50,000 (Negotiable)\n(Six lakh fifty tho...          3-0-0-0
#
#          HOUSE AREA  Unnamed: 3  BEDS  LIVING  KITCHEN  BATHROOMS  FLOORS  \
# 0  1200 SQUARE FEET         NaN   3.0     1.0      1.0        2.0     2.0
# ...

# %%
df.isnull().sum()
# Out:
# price             75
# LAND AREA         28
# HOUSE AREA       438
# Unnamed: 3       615
# BEDS             300
# LIVING           339
# KITCHEN          314
# BATHROOMS        375
# FLOORS           304
# FACED TOWARDS      8
# CATEGORY           0
# TYPE               0
# CODE               0
# UPDATE             0
# VIEWS              0
# FURNISHING       208
# FLAT AREA        598
# PARKING AREA     612
# dtype: int64

# %%
df = df.drop(columns={'HOUSE AREA','LIVING','KITCHEN','CODE','VIEWS','FURNISHING','FLAT AREA',''})
