# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset_ABADMBSM.csv')

# %%
df2 = pd.read_csv('Dataset_ABADMB_clean.csv')

# %%
df2.shape
# Out:
# (1986, 9)

# %%
df3 = pd.read_csv('Dataset_Combined_ADABMB.csv')

# %%
df2 = pd.read_csv('mergedd.csv')

# %%
df.describe()
# Out:
#        Price(Float)  Area(In Sq.Feet)         Road        Floor      Bedroom  \
# count  2.588000e+03       2588.000000  2588.000000  2588.000000  2588.000000
# mean   4.268288e+07       2117.919277    15.083037     2.768296     5.447836
# std    7.128729e+07       2409.443860     4.650731     0.814984     2.613630
# min    1.300000e+05         85.562500     2.000000     1.000000     1.000000
# 25%    2.350000e+07       1129.425000    13.000000     2.500000     4.000000
# 50%    3.150000e+07       1437.450000    13.000000     2.500000     5.000000
# 75%    4.512500e+07       2139.060000    17.625000     3.000000     6.000000
# max    3.150000e+09      68450.000000    50.000000    12.000000    36.000000
#
#           Bathroom
# count  2588.000000
# mean      4.032264
# std       1.835373
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max      34.000000

# %%
df.shape
# Out:
# (2588, 9)

# %%
df.corr()
# Out:
#                   Price(Float)  Area(In Sq.Feet)      Road     Floor  \
# Price(Float)          1.000000          0.248397  0.082528  0.151324
# Area(In Sq.Feet)      0.248397          1.000000  0.096454  0.021532
# Road                  0.082528          0.096454  1.000000  0.106000
# Floor                 0.151324          0.021532  0.106000  1.000000
# Bedroom               0.063415          0.050335  0.049823  0.468561
# Bathroom              0.145326          0.143130  0.119192  0.435777
#
#                    Bedroom  Bathroom
# Price(Float)      0.063415  0.145326
# Area(In Sq.Feet)  0.050335  0.143130
# Road              0.049823  0.119192
# Floor             0.468561  0.435777
# Bedroom           1.000000  0.599051
# Bathroom          0.599051  1.000000

# %%
import pandas as pd
import numpy as np
z_scores_Bedroom = np.abs((df2['Bedroom'] - df2['Bedroom'].mean()) / df2['Bedroom'].std())
threshold = 3
outliers_Bedroom = df2[z_scores_Bedroom > threshold]

# %%
z_scores_Bathroom = np.abs((df2['Bathroom'] - df2['Bathroom'].mean()) / df2['Bathroom'].std())
threshold = 3
outliers_Bathroom = df2[z_scores_Bathroom > threshold]

# %%
z_scores_Road= np.abs((df2['Road'] - df2['Road'].mean()) / df2['Road'].std())
threshold = 3
outliers_Road = df2[z_scores_Road> threshold]

# %%
z_scores_Price= np.abs((df['Price(Float)'] - df['Price(Float)'].mean()) / df['Price(Float)'].std())
threshold = 3
outliers_Price = df[z_scores_Price> threshold]

# %%
outliers_Price
# Out:
#       Price(Float)  Area(In Sq.Feet)  Road        Face  Floor  Bedroom  \
# 70       750000000       1060.975000  10.0       South    1.0        4
# 75       350000000       1500.000000  10.0  South east    3.0        7
# 681      295000000       1454.562500  13.0        East    2.5        7
# 822     3150000000       1369.000000  13.0        East    7.0        3
# 1728     290000000      18823.750000  15.0        East    2.0        6
# 1930     350000000      10952.000000  17.0        East    3.0        6
# 1981     260000000      17797.000000  18.0        East    3.0        5
# 1997     260000000       1779.700000  18.0        East    2.5        5
# 2042     266400000      12663.250000  20.0  South West    2.0        4
# 2069     310000000       1433.170000  20.0       South    2.5        4
# 2305     400000000      24984.250000  20.0        East    3.0        6
# 2373     269999999       5476.000000  20.0       South    2.5        6
# ...

# %%
z_scores_Area= np.abs((filtered_data['Area(In Sq.Feet)'] - filtered_data['Area(In Sq.Feet)'].mean()) / filtered_data['Area(In Sq.Feet)'].std())
threshold = 3
outliers_Area = filtered_data[z_scores_Area> threshold]

# %%
82140000
# Out:
# 82140000

# %%
filtered_data.to_csv('Dataset_ABADMB_Outlier_Removal_1st.csv',index=False)

# %%
quartiles = filtered_data.quantile([0.25, 0.5, 0.75])

# Access individual quartiles
q1 = quartiles.loc[0.25]
q2 = quartiles.loc[0.5]
q3 = quartiles.loc[0.75]

print("Quartile 1 (Q1):\n", q1)
print("Quartile 2 (Q2 or Median):\n", q2)
print("Quartile 3 (Q3):\n", q3)
# Out:
# Quartile 1 (Q1):
#  Price(Float)        2.400000e+07
# Area(In Sq.Feet)    1.129425e+03
# Road                1.300000e+01
# Floors              2.500000e+00
# Bedroom             4.000000e+00
# Bathroom            3.000000e+00
# Name: 0.25, dtype: float64
# Quartile 2 (Q2 or Median):
#  Price(Float)        32500000.00
# Area(In Sq.Feet)        1437.45
# Road                      13.00
# Floors                     2.50
# Bedroom                    5.00
# Bathroom                   4.00
# Name: 0.5, dtype: float64
# Quartile 3 (Q3):
#  Price(Float)        45000000.0
# Area(In Sq.Feet)        2053.5
# Road                      16.0
# Floors                     3.0
# Bedroom                    6.0
# Bathroom                   5.0
# Name: 0.75, dtype: float64

# %%
outliers_Area
# Out:
#       Price(Float)  Area(In Sq.Feet)  Road        Face  Floors  Bedroom  \
# 207    120000000.0        4791.50000  20.0        East     3.5      5.0
# 223     75000000.0        4449.25000  13.0       North     2.5      5.0
# 464     96000000.0        5476.00000  15.0  South East     2.5      7.0
# 474    110000000.0        5133.75000  15.0  North East     2.5      5.0
# 618    100000000.0        4791.50000  13.0       South     3.5      8.0
# 660    106000000.0        5202.20000  15.0        West     2.5      6.0
# 695     65000000.0        5202.20000  24.0        West     3.0      6.0
# 715     40000000.0        5202.20000  14.0       South     2.5      5.0
# 724     70000000.0        4517.70000  20.0        East     2.5      5.0
# 799     65000000.0        5476.00000  12.0        West     2.5      5.0
# 858     72500000.0        5476.00000  12.0       North     2.5      5.0
# 1051      150000.0        5476.00000  13.0        East     3.0      5.0
# ...

# %%
z_scores_Floor= np.abs((df2['Floors'] - df2['Floors'].mean()) / df2['Floors'].std())
threshold = 3
outliers_Floor = df2[z_scores_Floor> threshold]

# %%
print(len(outliers_Area)+len(outliers_Bathroom)+len(outliers_Bedroom)+len(outliers_Floor)+len(outliers_Price)+len(outliers_Road))
# Out:
# 180

# %%
df['Road'].mean(
)
# Out:
# 14.724229717528734

# %%
len(outliers)
# Out:
# 33

# %%
df2.shape
# Out:
# (1746, 9)

# %%
2349-1746
# Out:
# 603

# %%
# df2 = df2.drop(outliers_Area.index)
# df2 = df2.drop(outliers_Bathroom.index)
# df2 = df2.drop(outliers_Bedroom.index)
df2 = df2.drop(outliers_Floor.index)
# df2 = df2.drop(outliers_Price.index)
# df2 = df2.drop(outliers_Road.index)

# %%
5497/342.25
# Out:
# 16.06135865595325

# %%
12 ,0 0, 0 0, 0 0 0

# %%
filtered_data.mean()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13060\984522395.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   filtered_data.mean()
# Price(Float)        3.683866e+07
# Area(In Sq.Feet)    1.773267e+03
# Road                1.484673e+01
# Floors              2.775988e+00
# Bedroom             5.345289e+00
# Bathroom            4.044681e+00
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a dataframe named 'df'

# Create a histogram for each column in the dataframe
for column in filtered_data.columns:
    plt.figure()  # Create a new figure for each column
    filtered_data[column].plot(kind='hist', bins=10)  # Create a histogram with 10 bins
    plt.title(f"Histogram of {column}")  # Set the title of the histogram
    plt.xlabel(column)  # Set the x-axis label
    plt.ylabel("Frequency")  # Set the y-axis label
    plt.show()  # Display the histogram
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13060\1919999038.py in <module>
#       7 for column in filtered_data.columns:
#       8     plt.figure()  # Create a new figure for each column
# ----> 9     filtered_data[column].plot(kind='hist', bins=10)  # Create a histogram with 10 bins
#      10     plt.title(f"Histogram of {column}")  # Set the title of the histogram
#      11     plt.xlabel(column)  # Set the x-axis label
#
# D:\Softwares\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# D:\Softwares\anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a dataframe named 'df' with 'x' and 'y' columns

# Create a scatter plot
df2.plot(kind='scatter', x='Price(Float)', y='Area(In Sq.Feet)', color='blue', alpha=0.5)

# Perform linear regression and plot the regression line
coefficients = np.polyfit(df2['Price(Float)'], df2['Area(In Sq.Feet)'], 1)
polynomial = np.poly1d(coefficients)
plt.plot(df2['Price(Float)'], polynomial(df2['Price(Float)']), color='orange')

# Set the title and axis labels
plt.title('Regression Graph')
plt.xlabel('Price(Float)')
plt.ylabel('Area(In Sq.Feet)')

# Display the plot
plt.show()

# %%
columns_to_ignore = ['City', 'Address','Face','Floors','Bedroom','Bathroom']

min_values = df2.drop(columns=columns_to_ignore).min()

filtered_data = df2[~(df2 == min_values).any(axis=1)]
print(filtered_data)
# Out:
#       Price(Float)  Area(In Sq.Feet)  Road        Face  Floors  Bedroom  \
# 0       46500000.0          1471.675  13.0        West     3.0      6.0
# 1       35000000.0           855.625  13.0  South East     3.0      3.0
# 4       73500000.0          3114.475  13.0  South East     3.5      4.0
# 5       23000000.0          1026.750  13.0  South East     2.5      5.0
# 6       39000000.0          2053.500  14.0  South West     2.5      6.0
# ...            ...               ...   ...         ...     ...      ...
# 1974    55000000.0          2139.060  14.0        East     4.0      5.0
# 1975    29000000.0          2224.620  22.0       North     3.0      5.0
# 1976    30000000.0          1369.000  15.0       North     3.0      4.0
# 1977    60000000.0          3593.620  22.0  North East     4.0      5.0
# 1985    26000000.0          1369.000  14.0        East     2.5      6.0
#
#       Bathroom         Address       City
# 0          6.0   Hepali Height  Kathmandu
# ...

# %%
min_values
# Out:
# Price(Float)        130000.0000
# Area(In Sq.Feet)        85.5625
# Road                     3.0000
# Floors                   1.0000
# Bedroom                  1.0000
# Bathroom                 1.0000
# dtype: float64

# %%
filtered_data.min()
# Out:
# Price(Float)           150000.0
# Area(In Sq.Feet)          120.0
# Road                        4.0
# Face                       East
# Floors                      1.5
# Bedroom                     2.0
# Bathroom                    2.0
# Address             Aakasedhara
# City                  Bhaktapur
# dtype: object

# %%
# Data Processing
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer

# Modelling
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image


# Split the data into features (X) and target (y)
X = df.drop(columns=['Price(Float)'])
y = df['Price(Float)']
X_test1 = [1095.200,6.0,'East',6.0,22.0,8.0,'Old Baneshwor','Kathmandu']

Label_encoder = LabelEncoder()
nominal_cols = ['Face','Address','City']
transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')

X_encoded = transformer.fit_transform(X)
# # Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2)

regressor = RandomForestRegressor(n_estimators=100, random_state=0)
 
# fit the regressor with x and y data
model = regressor.fit(X_encoded, y)

y_pred = model.predict(X_test)



from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Assuming 'y_true' is the true target values and 'y_pred' is the predicted target values
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 178988079084469.78
# Root Mean Squared Error (RMSE): 13378642.647311788
# Mean Absolute Error (MAE): 4322054.06238302
# R-squared (R2): 0.8256420927703644

# %%
y_pred = model.predict(X_test1)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13060\1677265981.py in <module>
# ----> 1 y_pred = model.predict(X_test1)
#       2 mse = mean_squared_error(y_test, y_pred)
#       3 rmse = np.sqrt(mse)
#       4 mae = mean_absolute_error(y_test, y_pred)
#       5 r2 = r2_score(y_test, y_pred)
#
# D:\Softwares\anaconda\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     969         check_is_fitted(self)
#     970         # Check data
# --> 971         X = self._validate_X_predict(X)
#     972
#     973         # Assign chunk of trees to jobs
#
# D:\Softwares\anaconda\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     577         Validate X whenever one tries to predict, apply, predict_proba."""
#     578         check_is_fitted(self)
# ...

# %%
df['Address'].unique()
# Out:
# array(['Hepali Height', 'Sanepa', 'Old Baneshwor', 'Baluwatar',
#        'Manamaiju', 'Greenhill City', 'Budhanilkantha', 'Sainbu', 'Thali',
#        'Balkot', 'Bhaisepati', 'Pepsicola', 'Bijulibajar', 'Sundarbasti',
#        'Harisiddhi', 'Ghattekulo', 'Bhangal ', 'Baluwakhani', 'Lele',
#        'Syuchatar', 'Kapan', 'Khusibu Town Planning', 'Nakhipot',
#        'Sitapaila', 'Pasikot', 'Imadol', 'Mahadevtar', 'Sampang Chowk',
#        'Balambu', 'Ganesh Chowk', 'Makalbari', 'Thaiba', 'Tahachal',
#        'Lasuntar', 'Lubhu', 'Thecho', 'Hattiban', 'Naxal', 'Dhaksi',
#        'Bafal', 'Banasthali', 'Chabahil', 'Thankot', 'Danchhi',
#        'New Baneshwor', 'Kadaghari', 'Hattigaunda', 'Mahadevsthan',
#        'Gothatar', 'Dharmasthali', 'Kalanki', 'Saraswotinagar', 'Bhelpa',
#        'Taukhel', 'Dhapasi', 'Tikathali', 'Hattidanda', 'Golfutar',
#        'Mid Baneshwor', 'Thulobharyang', 'Satungal', 'Naya Basti',
#        'Matatirtha', 'Grande Hospital', 'Kupandole', 'Ekatabasti',
# ...

# %%
df.tail()
# Out:
#       Price(Float)  Area(In Sq.Feet)  Road        Face  Floors  Bedroom  \
# 2611   160000000.0           1540.08  32.0       South     2.5      4.0
# 2612    32000000.0           3080.00  32.0  South East     2.5      1.0
# 2613    70000000.0           5133.75  36.0        East     2.5      7.0
# 2614    11000000.0           1026.75  40.0  South East     2.0      3.0
# 2615    25000000.0           1818.20  44.0        East     2.5      8.0
#
#       Bathroom       Address       City
# 2611       3.0     Kathmandu  Kathmandu
# 2612       2.0  Gokarneshwor  Kathmandu
# 2613       4.0  Madhyapur-07  Bhaktapur
# 2614       2.0      Lalitpur   Lalitpur
# 2615       3.0  Gokarneshwor  Kathmandu

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load your regression dataset and split it into features and target variable
# X - Features, y - Target variable
X = df.drop(columns=['Price(Float)'])
y = df['Price(Float)']

Label_encoder = LabelEncoder()
nominal_cols = ['Face','Address','City']
transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')

X_encoded = transformer.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create an XGBoost regressor
model = xgb.XGBRegressor()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the mean squared error of the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9048\2118492928.py in <module>
#       8 y = df['Price(Float)']
#       9
# ---> 10 Label_encoder = LabelEncoder()
#      11 nominal_cols = ['Face','Address','City']
#      12 transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')
#
# NameError: name 'LabelEncoder' is not defined

# %%
pip install xgboost
# Out:
# ...
#      ---------------------------------------- 70.9/70.9 MB 4.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


def stepwise_selection(X, y, metric):
    columns = ['Face','Road','Address','Area(In Sq.Feet)','Bedroom','Bathroom','Floors']
    selected_features = []
    remaining_features = list(X)
    metrics = []
    
    while remaining_features:
        best_metric = float('inf')
        best_feature = None
        
        for feature in remaining_features:
            model = LinearRegression()
            model.fit(X[selected_features + [feature]], y)
            y_pred = model.predict(X[selected_features + [feature]])
            score = metric(y, y_pred)
            
            if score < best_metric:
                best_metric = score
                best_feature = feature
        
        if best_feature is not None:
            selected_features.append(best_feature)
            remaining_features.remove(best_feature)
            metrics.append(best_metric)
        else:
            break
    
    return selected_features, metrics

# Example usage
X = df.drop(columns=['Price(Float)'])
y = df['Price(Float)']

Label_encoder = LabelEncoder()
nominal_cols = ['Face','Address','City']
transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')

selected_features, metrics = stepwise_selection(X_encoded, y, mean_squared_error)

# Plotting
plt.plot(np.arange(1, len(selected_features) + 1), metrics, marker='o')
plt.xlabel('Number of Features')
plt.ylabel('Mean Squared Error')
plt.title('Stepwise Subset Selection')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19548\2779827779.py in <module>
#      43 transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')
#      44
# ---> 45 selected_features, metrics = stepwise_selection(X_encoded, y, mean_squared_error)
#      46
#      47 # Plotting
#
# ~\AppData\Local\Temp\ipykernel_19548\2779827779.py in stepwise_selection(X, y, metric)
#      18         for feature in remaining_features:
#      19             model = LinearRegression()
# ---> 20             model.fit(X[selected_features + [feature]], y)
#      21             y_pred = model.predict(X[selected_features + [feature]])
#      22             score = metric(y, y_pred)
#
# D:\Softwares\anaconda\lib\site-packages\scipy\sparse\_index.py in __getitem__(self, key)
#      45
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame called 'data' with actual column names
# Replace 'data' and 'feature_column' with your own DataFrame and column name

# Sort the features based on importance scores
sorted_features = df.sort_values(by='importance_column', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='importance_column', y='feature_column', df=sorted_features, palette='viridis')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19548\1403303217.py in <module>
#       7
#       8 # Sort the features based on importance scores
# ----> 9 sorted_features = df.sort_values(by='importance_column', ascending=False)
#      10
#      11 # Plotting
#
# D:\Softwares\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Softwares\anaconda\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6320
#    6321             by = by[0]
# -> 6322             k = self._get_label_or_level_values(by, axis=axis)
#    6323
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def stepwise_selection(X_encoded, y, metric):
    selected_features = []
    remaining_features = list(X_encoded.columns)
    metrics = []
    
    while remaining_features:
        best_metric = float('inf')
        best_feature = None
        
        for feature in remaining_features:
            model = LinearRegression()
            model.fit(X[selected_features + [feature]], y)
            y_pred = model.predict(X[selected_features + [feature]])
            score = metric(y, y_pred)
            
            if score < best_metric:
                best_metric = score
                best_feature = feature
        
        if best_feature is not None:
            selected_features.append(best_feature)
            remaining_features.remove(best_feature)
            metrics.append(best_metric)
        else:
            break
    
    return selected_features, metrics

# Example usage
X = df.drop(columns=['Price(Float)'])
y = df['Price(Float)']

Label_encoder = LabelEncoder()
nominal_cols = ['Face','Address','City']
transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')

selected_features, metrics = stepwise_selection(X_encoded, y, mean_squared_error)

# Plotting
plt.plot(np.arange(1, len(selected_features) + 1), metrics, marker='o')
plt.xlabel('Number of Features')
plt.ylabel('Mean Squared Error')
plt.title('Stepwise Subset Selection')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19548\2079358821.py in <module>
#      41 transformer = ColumnTransformer([('one_hot_encoder',OneHotEncoder(drop='first'),nominal_cols)],remainder='passthrough')
#      42
# ---> 43 selected_features, metrics = stepwise_selection(X_encoded, y, mean_squared_error)
#      44
#      45 # Plotting
#
# ~\AppData\Local\Temp\ipykernel_19548\2079358821.py in stepwise_selection(X_encoded, y, metric)
#       7 def stepwise_selection(X_encoded, y, metric):
#       8     selected_features = []
# ----> 9     remaining_features = list(X_encoded.columns)
#      10     metrics = []
#      11
#
# D:\Softwares\anaconda\lib\site-packages\scipy\sparse\_base.py in __getattr__(self, attr)
#     769             return self.getnnz()
#     770         else:
# --> 771             raise AttributeError(attr + " not found")
# ...

# %%
df2.shape
# Out:
# (1986, 9)

# %%
df2.corr()
# Out:
#                   Price(Float)  Area(In Sq.Feet)      Road    Floors  \
# Price(Float)          1.000000          0.539835  0.189950  0.125760
# Area(In Sq.Feet)      0.539835          1.000000  0.080134  0.007291
# Road                  0.189950          0.080134  1.000000  0.095241
# Floors                0.125760          0.007291  0.095241  1.000000
# Bedroom               0.148653          0.031387  0.035848  0.469791
# Bathroom              0.311440          0.131889  0.124499  0.437486
#
#                    Bedroom  Bathroom
# Price(Float)      0.148653  0.311440
# Area(In Sq.Feet)  0.031387  0.131889
# Road              0.035848  0.124499
# Floors            0.469791  0.437486
# Bedroom           1.000000  0.576022
# Bathroom          0.576022  1.000000

# %%
df2.max()
# Out:
# Price(Float)        400000000.0
# Area(In Sq.Feet)        68450.0
# Road                       50.0
# Face                       West
# Floors                     10.0
# Bedroom                    36.0
# Bathroom                   34.0
# Address             umang chowk
# City                   Lalitpur
# dtype: object

# %%
len(df2['Address'].unique())
# Out:
# 297

# %%
df2['Address'] = df2['Address'].str.strip()

# %%
len(df2['Address'].unique())
# Out:
# 330

# %%
df2['Address'] = df2['Address'].str.replace('-','')

# %%
import re

def remove_numbers(string):
    pattern = r'\d+'  # regex pattern to match one or more digits
    return re.sub(pattern, '', string)

# Example usage
for i,x in enumerate(df2['Address']):
    df2.loc[i,'Address'] = remove_numbers(x)
    print(df2.loc[i,'Address'])
# Out:
# Hepali Height
# Sanepa
# Old Baneshwor
# Baluwatar
# Manamaiju
# Greenhill City
# Budhanilkantha
# Sainbu
# Thali
# Balkot
# Budhanilkantha
# Bhaisepati
# Pepsicola
# Bijulibajar
# Sundarbasti
# Harisiddhi
# Ghattekulo
# Bhangal
# Baluwakhani
# Lele
# Syuchatar
# Kapan
# Khusibu Town Planning
# Nakhipot
# Sitapaila
# Pasikot
# Kapan
# Imadol
# Baluwakhani
# Mahadevtar
# Sampang Chowk
# Balambu
# Ganesh Chowk
# Bhaisepati
# Makalbari
# Thaiba
# Imadol
# Tahachal
# Lasuntar
# Imadol
# Imadol
# Lubhu
# Thecho
# Nakhipot
# Hattiban
# Naxal
# Dhaksi
# Bafal
# Banasthali
# Budhanilkantha
# Chabahil
# Thankot
# Sampang Chowk
# Danchhi
# New Baneshwor
# Kadaghari
# Hattigaunda
# Mahadevsthan
# Pasikot
# Bhaisepati
# Gothatar
# Dharmasthali
# Kalanki
# Imadol
# Sainbu
# Saraswotinagar
# Thecho
# Thecho
# Imadol
# Bhelpa
# Taukhel
# Baluwatar
# Dhapasi
# Tikathali
# Hattidanda
# Sainbu
# Golfutar
# Mid Baneshwor
# Hepali Height
# Thulo Bharyang
# Nakhipot
# Satungal
# Imadol
# Hattiban
# ...

# %%
df2['Address'] = df2['Address'].replace('Thulobharyang','Thulo Bharyang')

# %%
df2['Address']=df2['Address'].replace('Hepali height','Hepali Height')

# %%
df2['Address'] = df2['Address'].replace('height','Height')

# %%
df2['Address'] = df2['Address'].replace('Kageshworimanohara','Kageshwori Manohara')

# %%
df2['Address'] = df2['Address'].replace('ThuloBharyang','Thulo Bharyang')

# %%
df2['Address'] = df2['Address'].replace('Tennis Court','')

# %%
df2['Address'] = df2['Address'].replace('Grande Hospital','Tokha')

# %%
df2['Address'] = df2['Address'].replace('KageshwariManohara','Kageshwori Manohara')

# %%
df2['Address'] = df2['Address'].replace('Municipality','')

# %%
df2['Address'] = df2['Address'].replace('Kageshwori','Kageshwori Manohara')

# %%
import pandas as pd

# Assuming you have a dataframe named 'df' with multiple columns

# Iterate over the columns of the dataframe
for column in df2.columns:
    unique_values = df2[column].unique()  # Get unique values in the column
    num_unique_values = len(unique_values)  # Get the number of unique values
    
    # Check if the column has 333 unique values
    if num_unique_values == 333:
        print(f"Value counts for column '{column}':")
        
    
        
        # Or print a sample of the value counts
        sample = value_counts.head(60)  # Print the top 10 most frequent values
        print(sample)
        
        print()  # Add an empty line for separation
# Out:
# Value counts for column 'Address':
# Budhanilkantha    190
# Imadol            169
# Bhaisepati         91
# Dhapasi            47
# Sitapaila          42
# Kapan              35
# Basundhara         33
# Golfutar           33
# Baluwatar          28
# Tokha              28
# Hattiban           26
# Tikathali          26
# Pasikot            26
# Bhangal            24
# Nakkhu             21
# Hattigauda         20
# Bafal              20
# Pepsicola          19
# Samakhusi          19
# Kalanki            18
# Maharajgunj        18
# Syuchatar          17
# Sukedhara          16
# Nakhipot           16
# Banasthali         16
# Mandikatar         16
# Sanepa             14
# Gongabu            14
# Dhumbarahi         14
# Chapali            13
# Kadaghari          13
# Dhapakhel          13
# Goldhunga          12
# Chabahil           12
# Thulo Bharyang     12
# Hattigaunda        11
# Bansbari           11
# Gwarko             11
# Kusunti            11
# Koteshwor          10
# ...

# %%
df2.to_csv('Dataset_ABADMB_Clean.csv',index=False)
