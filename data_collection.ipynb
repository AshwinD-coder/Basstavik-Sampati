# %%
#This cell imports packages and modules for data collection and dataset engineering.

import os, time, csv, re
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd

# %%
#This cell initializes the chrome driver --> Creates a chrome tab for automation.

driver_path = 'C:/Program Files/Google/Chrome/Application/chromedriver.exe' # Use your Chromedriver.exe path here.
# driver = webdriver.Chrome('/path/to/chromedriver') 
service = Service(executable_path=driver_path)
#driver = webdriver.Chrome(service = service)
driver = webdriver.Chrome(driver_path)

# %%
#The code below are used as reference for using Selenium and BeautifulSoup for Data Collection.
#Source:https://www.codecademy.com/article/caupolicandiaz/web-scrape-with-selenium-and-beautiful-soup

# Print the href attribute of the anchor tag

# year_dd = driver.find_element_by_id('edition_select')
# year_options = year_dd.find_elements_by_tag_name('option')

# gender_dd = driver.find_element_by_id('athlete_gender') 
# gender_options = gender_dd.find_elements_by_tag_name('option')

# print(year_options[29].get_attribute('text'))

# usa_lst = []

# for gender in gender_options[1:]:
#     gender.click()
#     time.sleep(2)
#     gender_val = gender.get_attribute('text')
#     # print(year_options[0].get_attribute('text'))

#     for year in year_options[2:]:
#         year.click()
 
#         time.sleep(1) # provide time for processing the page update

#         the_soup = BeautifulSoup(driver.page_source, 'html.parser')
        

#         try:
#             year_val = year.get_attribute('text')
#             head = the_soup.find(href=re.compile('USA'))
  
#             medal_values = head.find_all_next('td',limit=5)
#             val_lst = [x.string for x in medal_values[-4:]]
            
#         except:
#             val_lst = ['0' for x in range(4)]

#         val_lst.append(gender_val)
#         val_lst.append(year_val)

#         usa_lst.append(val_lst)

#         if year_val == '2020':
#                 break

# driver.quit()

# print(usa_lst[30])
# print(usa_lst[31])


# try:
#     output_f = open('output.csv', 'w', newline='')
#     output_writer = csv.writer(output_f)
#     for row in usa_lst:
#         output_writer.writerow(row)

# except:
#     pass
# finally:
#     output_f.close()
#     print('done')

# %%
#Directs to the link inside of get method.
driver.get('https://basobaas.com/properties/for-sale/all/house') 

#anchor-tag stores selenium web element by using find elements by css selector method. 
anchor_tag = driver.find_elements_by_css_selector("a.property-card.featured")

house_links = [] #Created a list to store all the house links available in basobaas.com

# %%
clicker = driver.find_element_by_id('loadingBtn') #finding selenium web element for Load More Property Button
counter=0
try:
#Iterates and clicks on Load More Property Button until the Button span value is not Load More Property//takes time for complete execution
    for counter in range(4000000):
        clicker.click()
        span_value = (clicker.find_element_by_tag_name("span:not([id])")).get_attribute("innerText")
        time.sleep(4)
        if(span_value!="LOAD MORE PROPERTY "):
            break
except:
    print("error")
finally:
        for anchor in anchor_tag:
            house_links.append(anchor.get_attribute("href")) #appends all houselinks to house_link list

# %%
house_links = [] 
for anchor in anchor_tag:
            house_links.append(anchor.get_attribute("href"))#stores house links in list

# %%
#Calculating counts of house links in list
count = 0
for house in house_links:
    count+=1
    
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11628\2024190560.py in <module>
#       1 #Calculating counts of house links in list
#       2 count = 0
# ----> 3 for house in house_links:
#       4     count+=1
#       5
#
# NameError: name 'house_links' is not defined

# %%
with open("house_links.txt", "w") as f:
    for house in house_links:
        f.write(house+"\n") #Created a txt file with all house links from basobaas.com

# %%
driver2 = webdriver.Chrome(driver_path)

# %%
 #Filtering certain string patterns(re,re2,re3,re4) from the house links collected and created filtered_house_links.txt.
re = "https://basobaas.com/property/land-for-sale"
re2 = "https://basobaas.com/property/office-space"
re3 = "https://basobaas.com/premium"
re4 = "https://basobaas.com/property/business-for-sale"
house_links = []
correct_house_links = []
with open('house_links.txt', 'r') as file:
    for link in file:
        house_links.append(link)

correct_house_links = [item[0:-1] for item in house_links if re not in item]
correct_house_links = [item for item in correct_house_links if re2 not in item]
correct_house_links = [item for item in correct_house_links if re3 not in item]
correct_house_links = [item for item in correct_house_links if re4 not in item]
    
with open("filtered_house_links.txt", "w") as f:
    for house in correct_house_links:
        f.write(house+"\n")

# %%
#Opening filtered_house_links
correct_house_links = []
with open('filtered_house_links.txt', 'r') as file:
    for link in file:
        correct_house_links.append(link)

# %%
#Counting number of house_links in filtered_house_links.txt
count = 0
for x in correct_house_links:
    count+=1
    
print(count)
# Out:
# 2170

# %%
house_dictionary={}
title_val = []
address_val =[]
price = []
values = []
price = []
bedroom = []
bathroom = []
floor = []
parking = []
orientation = []
overview1 = []#group of features
overview2 = []#group of features
property_id=[]
property_face=[]
build_year = []
views = []
area_covered = []
road_access = []
build_area = []
posted = []
def fetch_feature():
    for link in correct_house_links[:266]:
        title_val.append(driver2.find_element_by_tag_name('h1').text)
        address_val.append(driver2.find_element_by_css_selector('div.address').text)
        price.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col4-xl.col4-md > div.value').text)
        bedroom.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(1) > div.value').text)
        bathroom.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(2) > div.value').text)
        floor.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(3) > div.value').text)
        parking.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(4) > div.value').text)
       
start_time = time.time()
fetch_feature()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 43.88752484321594 seconds ---

# %%
for x in correct_house_links[:266]:
    overview1.append(driver2.find_element(By.XPATH,"//*[@id='details-prop']/div/div[1]/div[1]/div[2]/div[2]/div/div[1]").text)
#         overview1.append(driver2.find_element(By.CLASS_NAME,"col-xl-6").text)
    overview2.append(driver2.find_element(By.XPATH,"//*[@id='details-prop']/div/div[1]/div[1]/div[2]/div[2]/div/div[2]").text)

def overview_manipulation(x):
        for item in x.split('\n'):
            key = item.split(':')[0].strip()
            value = item.split(':')[1].strip()
            if key == "Property Id":
                property_id.append(value)
            elif key == "Property Face":
                property_face.append(value)
            elif key == "Build Year":
                build_year.append(value)
            elif key == 'Views':
                views.append(value)
            elif key == "Area Covered":
                area_covered.append(value)
            elif key == "Road Access":
                road_access.append(value)
            elif key == "Build Up Area":
                build_area.append(value)
            elif key == "Posted":
                posted.append(value)

for item in overview1:    
    overview_manipulation(item)
    print(item)
for item in overview2:    
    overview_manipulation(item)
# Out:
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 137

# %%
print(property_face)
# Out:
# ['East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East']

# %%
house_dictionary.update({'title':title_val,'address':address_val,'price':price,'bedroom':bedroom,'bathroom':bathroom,'floor':floor,'parking':parking,'property_id':property_id,'property_face':property_face,'build_year':build_year,'views':views,'area_covered':area_covered,'road_access':road_access,'build_up_area':build_area,'posted':posted})

# %%
# house_dictionary={'title':[],'address':[],'price':[],'bedroom':[],'bathroom':[],'floor':[],'parking':[]}
# )
print(house_dictionary)
import pandas as pd
df_homedata = pd.DataFrame(house_dictionary)
df_homedata.to_csv('Dataset_house.csv')
# Out:
# {'title': ['New House For Sale At Puspalal Chowk Biratnagar For Sale : House For Sale In DDC Chowk, Biratnagar', 'New House For Sale At Puspalal Chowk Biratnagar For Sale : House For Sale In DDC Chowk, Biratnagar'], 'address': ['Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar', 'Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar'], 'price': ['NPR. 90,00,000 Onwards', 'NPR. 90,00,000 Onwards'], 'bedroom': ['3', '3'], 'bathroom': ['1', '1'], 'floor': ['1', '1'], 'parking': ['1', '1'], 'property_id': ['BN12539', 'BN12539'], 'property_face': ['East', 'East'], 'build_year': ['2021', '2021'], 'views': ['137', '137'], 'area_covered': ['10 Dhur', '10 Dhur'], 'road_access': ['20 Feet / Gravelled', '20 Feet / Gravelled'], 'build_up_area': ['7 Dhur', '7 Dhur'], 'posted': ['3 weeks ago', '3 weeks ago']}

# %%
df = pd.read_csv('Dataset_house.csv')
df.shape
# Out:
# (2, 16)

# %%
print(df.head())
# Out:
#    Unnamed: 0                                              title  \
# 0           0  New House For Sale At Puspalal Chowk Biratnaga...
# 1           1  New House For Sale At Puspalal Chowk Biratnaga...
#
#                                              address                   price  \
# 0  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
# 1  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
#
#    bedroom  bathroom  floor  parking property_id property_face  build_year  \
# 0        3         1      1        1     BN12539          East        2021
# 1        3         1      1        1     BN12539          East        2021
#
#    views area_covered          road_access build_up_area       posted
# 0    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
# 1    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
