# %%
#This cell imports packages and modules for data collection and dataset engineering.

import os, time, csv, re
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd

# %%
#This cell initializes the chrome driver --> Creates a chrome tab for automation.

driver_path = 'C:/Program Files/Google/Chrome/Application/chromedriver.exe' # Use your Chromedriver.exe path here.
# driver = webdriver.Chrome('/path/to/chromedriver') 
service = Service(executable_path=driver_path)
#driver = webdriver.Chrome(service = service)
driver = webdriver.Chrome(driver_path)

# %%
#The code below are used as reference for using Selenium and BeautifulSoup for Data Collection.
#Source:https://www.codecademy.com/article/caupolicandiaz/web-scrape-with-selenium-and-beautiful-soup

# Print the href attribute of the anchor tag

# year_dd = driver.find_element_by_id('edition_select')
# year_options = year_dd.find_elements_by_tag_name('option')

# gender_dd = driver.find_element_by_id('athlete_gender') 
# gender_options = gender_dd.find_elements_by_tag_name('option')

# print(year_options[29].get_attribute('text'))

# usa_lst = []

# for gender in gender_options[1:]:
#     gender.click()
#     time.sleep(2)
#     gender_val = gender.get_attribute('text')
#     # print(year_options[0].get_attribute('text'))

#     for year in year_options[2:]:
#         year.click()
 
#         time.sleep(1) # provide time for processing the page update

#         the_soup = BeautifulSoup(driver.page_source, 'html.parser')
        

#         try:
#             year_val = year.get_attribute('text')
#             head = the_soup.find(href=re.compile('USA'))
  
#             medal_values = head.find_all_next('td',limit=5)
#             val_lst = [x.string for x in medal_values[-4:]]
            
#         except:
#             val_lst = ['0' for x in range(4)]

#         val_lst.append(gender_val)
#         val_lst.append(year_val)

#         usa_lst.append(val_lst)

#         if year_val == '2020':
#                 break

# driver.quit()

# print(usa_lst[30])
# print(usa_lst[31])


# try:
#     output_f = open('output.csv', 'w', newline='')
#     output_writer = csv.writer(output_f)
#     for row in usa_lst:
#         output_writer.writerow(row)

# except:
#     pass
# finally:
#     output_f.close()
#     print('done')

# %%
#Directs to the link inside of get method.
driver.get('https://basobaas.com/properties/for-sale/all/house') 

#anchor-tag stores selenium web element by using find elements by css selector method. 
anchor_tag = driver.find_elements_by_css_selector("a.property-card.featured")

house_links = [] #Created a list to store all the house links available in basobaas.com

# %%
clicker = driver.find_element_by_id('loadingBtn') #finding selenium web element for Load More Property Button
counter=0
try:
#Iterates and clicks on Load More Property Button until the Button span value is not Load More Property//takes time for complete execution
    for counter in range(4000000):
        clicker.click()
        span_value = (clicker.find_element_by_tag_name("span:not([id])")).get_attribute("innerText")
        time.sleep(4)
        if(span_value!="LOAD MORE PROPERTY "):
            break
except:
    print("error")
finally:
        for anchor in anchor_tag:
            house_links.append(anchor.get_attribute("href")) #appends all houselinks to house_link list

# %%
house_links = [] 
for anchor in anchor_tag:
            house_links.append(anchor.get_attribute("href"))#stores house links in list

# %%
#Calculating counts of house links in list
count = 0
for house in house_links:
    count+=1
    
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11628\2024190560.py in <module>
#       1 #Calculating counts of house links in list
#       2 count = 0
# ----> 3 for house in house_links:
#       4     count+=1
#       5
#
# NameError: name 'house_links' is not defined

# %%
with open("house_links.txt", "w") as f:
    for house in house_links:
        f.write(house+"\n") #Created a txt file with all house links from basobaas.com

# %%
driver2 = webdriver.Chrome(driver_path)

# %%
 #Filtering certain string patterns(re,re2,re3,re4) from the house links collected and created filtered_house_links.txt.
re = "https://basobaas.com/property/land-for-sale"
re2 = "https://basobaas.com/property/office-space"
re3 = "https://basobaas.com/premium"
re4 = "https://basobaas.com/property/business-for-sale"
house_links = []
correct_house_links = []
with open('house_links.txt', 'r') as file:
    for link in file:
        house_links.append(link)

correct_house_links = [item[0:-1] for item in house_links if re not in item]
correct_house_links = [item for item in correct_house_links if re2 not in item]
correct_house_links = [item for item in correct_house_links if re3 not in item]
correct_house_links = [item for item in correct_house_links if re4 not in item]
    
with open("filtered_house_links.txt", "w") as f:
    for house in correct_house_links:
        f.write(house+"\n")

# %%
#Opening filtered_house_links
correct_house_links = []
with open('filtered_house_links.txt', 'r') as file:
    for link in file:
        correct_house_links.append(link)

# %%
#Counting number of house_links in filtered_house_links.txt
count = 0
for x in correct_house_links:
    count+=1
    
print(count)
# Out:
# 2170

# %%
house_dictionary={}
title_val = []
address_val =[]
price = []
values = []
price = []
bedroom = []
bathroom = []
floor = []
parking = []
orientation = []
overview1 = []#group of features
overview2 = []#group of features
property_id=[]
property_face=[]
build_year = []
views = []
area_covered = []
road_access = []
build_area = []
posted = []
def fetch_feature():
    for link in correct_house_links[:266]:
        driver2.get(link)
        title_val.append(driver2.find_element_by_tag_name('h1').text)
        address_val.append(driver2.find_element_by_css_selector('div.address').text)
        price.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col4-xl.col4-md > div.value').text)
        bedroom.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(1) > div.value').text)
        bathroom.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(2) > div.value').text)
        floor.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(3) > div.value').text)
        parking.append(driver2.find_element_by_css_selector('#details-prop > div > div.row > div.col-xl-8 > div:nth-child(1) > div > div > div.col8-xl.col8-md > div > div:nth-child(4) > div.value').text)
        overview1.append(driver2.find_element(By.XPATH,"//*[@id='details-prop']/div/div[1]/div[1]/div[2]/div[2]/div/div[1]").text)
#         overview1.append(driver2.find_element(By.CLASS_NAME,"col-xl-6").text)
        overview2.append(driver2.find_element(By.XPATH,"//*[@id='details-prop']/div/div[1]/div[1]/div[2]/div[2]/div/div[2]").text)
start_time = time.time()
fetch_feature()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 890.5153739452362 seconds ---

# %%
    

def overview_manipulation(x):
        for item in x.split('\n'):
            key = item.split(':')[0].strip()
            value = item.split(':')[1].strip()
            if key == "Property Id":
                property_id.append(value)
            elif key == "Property Face":
                property_face.append(value)
            elif key == "Build Year":
                build_year.append(value)
            elif key == 'Views':
                views.append(value)
            elif key == "Area Covered":
                area_covered.append(value)
            elif key == "Road Access":
                road_access.append(value)
            elif key == "Build Up Area":
                build_area.append(value)
            elif key == "Posted":
                posted.append(value)

for item in overview1:    
    overview_manipulation(item)
    print(item)
for item in overview2:    
    overview_manipulation(item)
# Out:
# Property Id : BN12544
# Property Face : East
# Build Year :N/A
# Views : 193
# Property Id : BN12539
# Property Face : East
# Build Year : 2021
# Views : 138
# Property Id : BN12537
# Property Face : North
# Build Year :N/A
# Views : 142
# Property Id : BN12534
# Property Face : North
# Build Year :N/A
# Views : 182
# Property Id : BN12529
# Property Face : East
# Build Year : 2079
# Views : 172
# Property Id : BN12528
# Property Face : South East
# Build Year :N/A
# Views : 247
# Property Id : BN12522
# Property Face : East
# Build Year : 2017
# Views : 158
# Property Id : BN12520
# Property Face : East
# Build Year :N/A
# Views : 173
# Property Id : BN12519
# Property Face : South
# Build Year :N/A
# Views : 114
# Property Id : BN12511
# Property Face : East
# Build Year :N/A
# Views : 128
# Property Id : BN12491
# Property Face : North East
# Build Year : 2022
# Views : 187
# Property Id : BN12490
# Property Face : North East
# Build Year :N/A
# Views : 158
# Property Id : BN12489
# Property Face : North
# Build Year : 2073
# Views : 127
# Property Id : BN12488
# Property Face : North
# Build Year : 2073
# Views : 100
# Property Id : BN12483
# Property Face : South East
# Build Year :N/A
# Views : 678
# Property Id : BN12481
# Property Face : East
# Build Year : 2073
# Views : 215
# Property Id : BN12480
# Property Face : East
# Build Year : 2065
# Views : 180
# Property Id : BN12478
# Property Face : North East
# Build Year : 2023
# Views : 257
# Property Id : BN12465
# Property Face : South West
# Build Year : 2076
# Views : 270
# Property Id : BN12463
# Property Face : South East
# Build Year : 2050
# Views : 289
# Property Id : BN12491
# Property Face : North East
# Build Year : 2022
# Views : 188
# Property Id : BN12490
# Property Face : North East
# Build Year :N/A
# Views : 159
# Property Id : BN12489
# Property Face : North
# Build Year : 2073
# Views : 128
# Property Id : BN12488
# Property Face : North
# Build Year : 2073
# Views : 101
# Property Id : BN12483
# Property Face : South East
# Build Year :N/A
# Views : 679
# Property Id : BN12481
# Property Face : East
# Build Year : 2073
# Views : 216
# Property Id : BN12480
# Property Face : East
# Build Year : 2065
# Views : 181
# Property Id : BN12478
# Property Face : North East
# Build Year : 2023
# Views : 258
# Property Id : BN12465
# Property Face : South West
# Build Year : 2076
# Views : 271
# Property Id : BN12463
# Property Face : South East
# Build Year : 2050
# Views : 290
# Property Id : BN12459
# Property Face : North East
# Build Year :N/A
# Views : 219
# Property Id : BN12453
# Property Face : North
# Build Year : 2022
# Views : 325
# Property Id : BN12450
# Property Face : North West
# Build Year :N/A
# Views : 276
# Property Id : BN12447
# Property Face : West
# Build Year : 2066
# Views : 252
# Property Id : BN12446
# Property Face : South
# Build Year :N/A
# Views : 201
# Property Id : BN12432
# Property Face : South
# Build Year : 2019
# Views : 294
# Property Id : BN12429
# Property Face : South East
# Build Year : 2071
# Views : 233
# Property Id : BN12428
# Property Face : East
# Build Year : 2064
# Views : 15.1K
# Property Id : BN12426
# Property Face : South East
# Build Year :N/A
# Views : 526
# Property Id : BN12419
# Property Face : South
# Build Year : 2023
# Views : 395
# Property Id : BN12408
# Property Face : East
# Build Year :N/A
# Views : 103
# Property Id : BN12399
# Property Face : South
# Build Year : 2072
# Views : 226
# Property Id : BN12394
# Property Face : North East
# Build Year : 2075
# Views : 249
# Property Id : BN12388
# Property Face : North West
# Build Year : 2074
# Views : 178
# Property Id : BN12368
# Property Face : East
# Build Year :N/A
# Views : 300
# Property Id : BN12367
# Property Face : East
# Build Year : 2072
# Views : 246
# Property Id : BN12364
# Property Face : East
# Build Year : 2075
# Views : 2.1K
# Property Id : BN12355
# Property Face : East
# Build Year : 2016
# Views : 227
# Property Id : BN12351
# Property Face : East
# Build Year : 2022
# Views : 315
# Property Id : BN12350
# Property Face : North
# Build Year :N/A
# Views : 119
# Property Id : BN12345
# Property Face : East
# Build Year : 2077
# Views : 190
# Property Id : BN12343
# Property Face : East
# Build Year : 2015
# Views : 250
# Property Id : BN12336
# Property Face : East
# Build Year : 2004
# Views : 379
# Property Id : BN12309
# Property Face : South East
# Build Year :N/A
# Views : 1.8K
# Property Id : BN12308
# Property Face : East
# Build Year :N/A
# Views : 749
# Property Id : BN12300
# Property Face : North
# Build Year : 2072
# Views : 905
# Property Id : BN12299
# Property Face : South West
# Build Year :N/A
# Views : 1.1K
# Property Id : BN12297
# Property Face : South
# Build Year :N/A
# Views : 371
# Property Id : BN12295
# Property Face : South East
# Build Year : 2077
# Views : 548
# Property Id : BN12293
# Property Face : East
# Build Year :N/A
# Views : 326
# Property Id : BN12280
# Property Face : South
# Build Year : 2022
# Views : 554
# Property Id : BN12279
# Property Face : South
# Build Year : 2077
# Views : 277
# Property Id : BN12277
# Property Face : North
# Build Year : 2066
# Views : 566
# Property Id : BN12275
# Property Face : North
# Build Year : 2078
# Views : 1.6K
# Property Id : BN12237
# Property Face : East
# Build Year :N/A
# Views : 209
# Property Id : BN12236
# Property Face : East
# Build Year :N/A
# Views : 243
# Property Id : BN12234
# Property Face : East
# Build Year : 2077
# Views : 144
# Property Id : BN12232
# Property Face : East
# Build Year :N/A
# Views : 493
# Property Id : BN12226
# Property Face : South
# Build Year :N/A
# Views : 442
# Property Id : BN12196
# Property Face : South
# Build Year :N/A
# Views : 882
# Property Id : BN12130
# Property Face : South
# Build Year :N/A
# Views : 1.2K
# Property Id : BN12129
# Property Face : North East
# Build Year :N/A
# Views : 923
# Property Id : BN12128
# Property Face : West
# Build Year :N/A
# Views : 1.2K
# Property Id : BN12120
# Property Face : East
# Build Year :N/A
# Views : 421
# Property Id : BN12119
# Property Face : North
# Build Year : 2077
# Views : 409
# Property Id : BN12118
# Property Face : South
# Build Year : 2022
# Views : 302
# Property Id : BN12116
# Property Face : South
# Build Year :N/A
# Views : 244
# Property Id : BN12115
# Property Face : East
# Build Year : 2022
# Views : 233
# Property Id : BN12113
# Property Face : South
# Build Year :N/A
# Views : 265
# Property Id : BN11981
# Property Face : East
# Build Year :N/A
# Views : 993
# Property Id : BN11918
# Property Face : South
# Build Year :N/A
# Views : 1.5K
# Property Id : BN11917
# Property Face : North West
# Build Year : 2016
# Views : 421
# Property Id : BN11911
# Property Face : East
# Build Year : 2019
# Views : 400
# Property Id : BN11906
# Property Face : East
# Build Year : 2022
# Views : 670
# Property Id : BN11901
# Property Face : South
# Build Year : 2079
# Views : 445
# Property Id : BN11893
# Property Face : East
# Build Year : 2000
# Views : 377
# Property Id : BN11892
# Property Face : West
# Build Year : 2078
# Views : 1.4K
# Property Id : BN11890
# Property Face : West
# Build Year : 2078
# Views : 5K
# Property Id : BN11889
# Property Face : North East
# Build Year : 2079
# Views : 1.1K
# Property Id : BN11888
# Property Face : South East
# Build Year : 2016
# Views : 270
# Property Id : BN11885
# Property Face : South
# Build Year :N/A
# Views : 633
# Property Id : BN11877
# Property Face : South East
# Build Year :N/A
# Views : 821
# Property Id : BN11874
# Property Face : East
# Build Year :N/A
# Views : 298
# Property Id : BN11873
# Property Face : East
# Build Year :N/A
# Views : 754
# Property Id : BN11871
# Property Face : East
# Build Year :N/A
# Views : 702
# Property Id : BN11870
# Property Face : South
# Build Year :N/A
# Views : 535
# Property Id : BN11811
# Property Face : West
# Build Year : 2077
# Views : 1.7K
# Property Id : BN11804
# Property Face : East
# Build Year : 2074
# Views : 303
# Property Id : BN11797
# Property Face : South
# Build Year :N/A
# Views : 665
# Property Id : BN11790
# Property Face : North
# Build Year :N/A
# Views : 1.2K
# Property Id : BN11788
# Property Face : North
# Build Year :N/A
# Views : 688
# Property Id : BN11785
# Property Face : East
# Build Year :N/A
# Views : 486
# Property Id : BN11784
# Property Face : East
# Build Year :N/A
# Views : 488
# Property Id : BN11783
# Property Face : East
# Build Year :N/A
# Views : 4.8K
# Property Id : BN11782
# Property Face : East
# Build Year :N/A
# Views : 291
# Property Id : BN11781
# Property Face : South East
# Build Year : 2019
# Views : 627
# Property Id : BN11778
# Property Face : West
# Build Year : 2077
# Views : 549
# Property Id : BN11773
# Property Face : East
# Build Year :N/A
# Views : 282
# Property Id : BN11765
# Property Face : South East
# Build Year : 2065
# Views : 501
# Property Id : BN11764
# Property Face : East
# Build Year : 2072
# Views : 444
# Property Id : BN11755
# Property Face : North
# Build Year :N/A
# Views : 471
# Property Id : BN11754
# Property Face : South
# Build Year : 2077
# Views : 867
# Property Id : BN11740
# Property Face : East
# Build Year : 2022
# Views : 841
# Property Id : BN11733
# Property Face : East
# Build Year : 2018
# Views : 616
# Property Id : BN11723
# Property Face : North East
# Build Year : 2016
# Views : 421
# Property Id : BN11718
# Property Face : South
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11715
# Property Face : South
# Build Year : 2076
# Views : 684
# Property Id : BN11710
# Property Face : South East
# Build Year : 2065
# Views : 866
# Property Id : BN11706
# Property Face : South East
# Build Year : 2012
# Views : 1K
# Property Id : BN11703
# Property Face : South
# Build Year : 2068
# Views : 950
# Property Id : BN11701
# Property Face : South
# Build Year :N/A
# Views : 376
# Property Id : BN11699
# Property Face : North East
# Build Year :N/A
# Views : 778
# Property Id : BN11696
# Property Face : West
# Build Year :N/A
# Views : 878
# Property Id : BN11695
# Property Face : West
# Build Year :N/A
# Views : 446
# Property Id : BN11694
# Property Face : West
# Build Year :N/A
# Views : 419
# Property Id : BN11693
# Property Face : North East
# Build Year : 2078
# Views : 785
# Property Id : BN11681
# Property Face : West
# Build Year :N/A
# Views : 797
# Property Id : BN11680
# Property Face : East
# Build Year :N/A
# Views : 727
# Property Id : BN11674
# Property Face : North
# Build Year :N/A
# Views : 789
# Property Id : BN11673
# Property Face : South
# Build Year : 2079
# Views : 6.3K
# Property Id : BN11672
# Property Face : East
# Build Year :N/A
# Views : 678
# Property Id : BN11665
# Property Face : West
# Build Year :N/A
# Views : 838
# Property Id : BN11664
# Property Face : North
# Build Year :N/A
# Views : 1.3K
# Property Id : BN11662
# Property Face : North East
# Build Year :N/A
# Views : 7.6K
# Property Id : BN11654
# Property Face : West
# Build Year :N/A
# Views : 933
# Property Id : BN11652
# Property Face : South
# Build Year :N/A
# Views : 459
# Property Id : BN11644
# Property Face : South East
# Build Year :N/A
# Views : 839
# Property Id : BN11640
# Property Face : South East
# Build Year : 2076
# Views : 582
# Property Id : BN11628
# Property Face : South
# Build Year : 2079
# Views : 892
# Property Id : BN11624
# Property Face : South West
# Build Year :N/A
# Views : 1.2K
# Property Id : BN11623
# Property Face : East
# Build Year :N/A
# Views : 650
# Property Id : BN11622
# Property Face : North East
# Build Year : 2066
# Views : 680
# Property Id : BN11621
# Property Face : West
# Build Year : 2069
# Views : 864
# Property Id : BN11619
# Property Face : South
# Build Year : 2077
# Views : 514
# Property Id : BN11612
# Property Face : East
# Build Year :N/A
# Views : 1.2K
# Property Id : BN11611
# Property Face : South
# Build Year : 2068
# Views : 8.3K
# Property Id : BN11609
# Property Face : East
# Build Year : 2079
# Views : 802
# Property Id : BN11607
# Property Face : East
# Build Year :N/A
# Views : 1.3K
# Property Id : BN11605
# Property Face : East
# Build Year :N/A
# Views : 604
# Property Id : BN11595
# Property Face : North
# Build Year :N/A
# Views : 653
# Property Id : BN11587
# Property Face : East
# Build Year :N/A
# Views : 1.8K
# Property Id : BN11581
# Property Face : North East
# Build Year : 2021
# Views : 1.1K
# Property Id : BN11579
# Property Face : East
# Build Year :N/A
# Views : 1.2K
# Property Id : BN11576
# Property Face : North
# Build Year : 2022
# Views : 1K
# Property Id : BN11572
# Property Face : East
# Build Year : 2079
# Views : 1.1K
# Property Id : BN11571
# Property Face : East
# Build Year : 2079
# Views : 785
# Property Id : BN11570
# Property Face : East
# Build Year : 2079
# Views : 741
# Property Id : BN11569
# Property Face : South West
# Build Year : 2022
# Views : 881
# Property Id : BN11568
# Property Face : East
# Build Year : 2022
# Views : 614
# Property Id : BN11560
# Property Face : East
# Build Year : 2015
# Views : 472
# Property Id : BN11556
# Property Face : South
# Build Year : 2079
# Views : 860
# Property Id : BN11555
# Property Face : East
# Build Year : 2079
# Views : 695
# Property Id : BN11554
# Property Face : East
# Build Year : 2079
# Views : 933
# Property Id : BN11553
# Property Face : South West
# Build Year : 2074
# Views : 771
# Property Id : BN11552
# Property Face : South East
# Build Year : 2079
# Views : 479
# Property Id : BN11551
# Property Face : East
# Build Year : 2079
# Views : 625
# Property Id : BN11550
# Property Face : East
# Build Year : 2079
# Views : 401
# Property Id : BN11549
# Property Face : East
# Build Year : 2079
# Views : 606
# Property Id : BN11548
# Property Face : East
# Build Year :N/A
# Views : 512
# Property Id : BN11547
# Property Face : East
# Build Year : 2014
# Views : 624
# Property Id : BN11542
# Property Face : South
# Build Year : 2078
# Views : 678
# Property Id : BN11541
# Property Face : South East
# Build Year : 2079
# Views : 498
# Property Id : BN11540
# Property Face : East
# Build Year : 2079
# Views : 854
# Property Id : BN11539
# Property Face : East
# Build Year : 2079
# Views : 856
# Property Id : BN11525
# Property Face : East
# Build Year : 2079
# Views : 487
# Property Id : BN11522
# Property Face : North East
# Build Year :N/A
# Views : 805
# Property Id : BN11512
# Property Face : South West
# Build Year : 2015
# Views : 831
# Property Id : BN11510
# Property Face : East
# Build Year : 2078
# Views : 905
# Property Id : BN11509
# Property Face : East
# Build Year : 2078
# Views : 694
# Property Id : BN11508
# Property Face : South East
# Build Year : 2078
# Views : 659
# Property Id : BN11507
# Property Face : South
# Build Year : 2077
# Views : 645
# Property Id : BN11496
# Property Face : North
# Build Year :N/A
# Views : 6.1K
# Property Id : BN11490
# Property Face : East
# Build Year : 2021
# Views : 497
# Property Id : BN11487
# Property Face : East
# Build Year : 2077
# Views : 467
# Property Id : BN11486
# Property Face : East
# Build Year :N/A
# Views : 344
# Property Id : BN11483
# Property Face : East
# Build Year : 2017
# Views : 748
# Property Id : BN11458
# Property Face : East
# Build Year : 2075
# Views : 1K
# Property Id : BN11451
# Property Face : South
# Build Year :N/A
# Views : 567
# Property Id : BN11450
# Property Face : North East
# Build Year :N/A
# Views : 461
# Property Id : BN11449
# Property Face : East
# Build Year :N/A
# Views : 874
# Property Id : BN11424
# Property Face : South
# Build Year :N/A
# Views : 749
# Property Id : BN11421
# Property Face : North
# Build Year : 2078
# Views : 846
# Property Id : BN11419
# Property Face : South
# Build Year :N/A
# Views : 695
# Property Id : BN11416
# Property Face : East
# Build Year : 2021
# Views : 916
# Property Id : BN11415
# Property Face : West
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11414
# Property Face : East
# Build Year : 2022
# Views : 368
# Property Id : BN11410
# Property Face : North
# Build Year : 2078
# Views : 4.5K
# Property Id : BN11409
# Property Face : North
# Build Year : 2078
# Views : 1.3K
# Property Id : BN11408
# Property Face : East
# Build Year : 2078
# Views : 7.1K
# Property Id : BN11407
# Property Face : East
# Build Year : 2078
# Views : 1K
# Property Id : BN11406
# Property Face : East
# Build Year : 2078
# Views : 543
# Property Id : BN11388
# Property Face : East
# Build Year :N/A
# Views : 363
# Property Id : BN11386
# Property Face : East
# Build Year :N/A
# Views : 695
# Property Id : BN11381
# Property Face : North East
# Build Year : 2075
# Views : 1K
# Property Id : BN11376
# Property Face : East
# Build Year :N/A
# Views : 393
# Property Id : BN11373
# Property Face : North
# Build Year :N/A
# Views : 585
# Property Id : BN11371
# Property Face : East
# Build Year :N/A
# Views : 963
# Property Id : BN11369
# Property Face : South West
# Build Year :N/A
# Views : 12.5K
# Property Id : BN11368
# Property Face : East
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11358
# Property Face : East
# Build Year :N/A
# Views : 910
# Property Id : BN11352
# Property Face : South
# Build Year :N/A
# Views : 2.6K
# Property Id : BN11337
# Property Face : North West
# Build Year : 2078
# Views : 860
# Property Id : BN11336
# Property Face : South
# Build Year : 2078
# Views : 5.7K
# Property Id : BN11335
# Property Face : East
# Build Year :N/A
# Views : 2.6K
# Property Id : BN11334
# Property Face : East
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11333
# Property Face : North
# Build Year :N/A
# Views : 525
# Property Id : BN11332
# Property Face : South
# Build Year :N/A
# Views : 1.5K
# Property Id : BN11329
# Property Face : North West
# Build Year : 2048
# Views : 4.5K
# Property Id : BN11328
# Property Face : East
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11324
# Property Face : South
# Build Year : 2078
# Views : 2.9K
# Property Id : BN11319
# Property Face : South
# Build Year :N/A
# Views : 440
# Property Id : BN11318
# Property Face : West
# Build Year :N/A
# Views : 929
# Property Id : BN11315
# Property Face : West
# Build Year :N/A
# Views : 576
# Property Id : BN11309
# Property Face : East
# Build Year : 2020
# Views : 1K
# Property Id : BN11293
# Property Face : South East
# Build Year : 2015
# Views : 836
# Property Id : BN11288
# Property Face : West
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11267
# Property Face : East
# Build Year : 2066
# Views : 1.5K
# Property Id : BN11260
# Property Face : East
# Build Year : 2076
# Views : 742
# Property Id : BN11250
# Property Face : West
# Build Year : 2078
# Views : 372
# Property Id : BN11244
# Property Face : East
# Build Year : 2058
# Views : 691
# Property Id : BN11243
# Property Face : East
# Build Year : 2073
# Views : 9.2K
# Property Id : BN11242
# Property Face : North East
# Build Year : 2076
# Views : 1.2K
# Property Id : BN11239
# Property Face : West
# Build Year : 2008
# Views : 952
# Property Id : BN11236
# Property Face : North West
# Build Year :N/A
# Views : 998
# Property Id : BN11230
# Property Face : South
# Build Year :N/A
# Views : 581
# Property Id : BN11213
# Property Face : North West
# Build Year :N/A
# Views : 1.3K
# Property Id : BN11212
# Property Face : North
# Build Year : 2020
# Views : 817
# Property Id : BN11211
# Property Face : East
# Build Year :N/A
# Views : 797
# Property Id : BN11210
# Property Face : East
# Build Year :N/A
# Views : 736
# Property Id : BN11209
# Property Face : East
# Build Year :N/A
# Views : 571
# Property Id : BN11200
# Property Face : South East
# Build Year : 2022
# Views : 1K
# Property Id : BN11198
# Property Face : South East
# Build Year :N/A
# Views : 949
# Property Id : BN11194
# Property Face : South East
# Build Year :N/A
# Views : 982
# Property Id : BN11190
# Property Face : East
# Build Year :N/A
# Views : 856
# Property Id : BN11189
# Property Face : North West
# Build Year :N/A
# Views : 584
# Property Id : BN11186
# Property Face : East
# Build Year : 2078
# Views : 861
# Property Id : BN11181
# Property Face : East
# Build Year :N/A
# Views : 1.2K
# Property Id : BN11180
# Property Face : East
# Build Year :N/A
# Views : 679
# Property Id : BN11179
# Property Face : South West
# Build Year : 2018
# Views : 1.1K
# Property Id : BN11174
# Property Face : South East
# Build Year :N/A
# Views : 769
# Property Id : BN11173
# Property Face : North East
# Build Year : 2073
# Views : 6K
# Property Id : BN11168
# Property Face : South
# Build Year : 2002
# Views : 647
# Property Id : BN11165
# Property Face : West
# Build Year :N/A
# Views : 850
# Property Id : BN11158
# Property Face : North
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11155
# Property Face : North
# Build Year :N/A
# Views : 916
# Property Id : BN11148
# Property Face : East
# Build Year :N/A
# Views : 342
# Property Id : BN11142
# Property Face : West
# Build Year :N/A
# Views : 984
# Property Id : BN11133
# Property Face : West
# Build Year : 2077
# Views : 336
# Property Id : BN11126
# Property Face : West
# Build Year :N/A
# Views : 1K
# Property Id : BN11125
# Property Face : West
# Build Year :N/A
# Views : 2.5K
# Property Id : BN11124
# Property Face : West
# Build Year :N/A
# Views : 591
# Property Id : BN11123
# Property Face : North
# Build Year :N/A
# Views : 619
# Property Id : BN11122
# Property Face : South
# Build Year :N/A
# Views : 1.1K
# Property Id : BN11117
# Property Face : South
# Build Year :N/A
# Views : 647
# Property Id : BN11115
# Property Face : East
# Build Year : 2078
# Views : 602
# Property Id : BN11109
# Property Face : South
# Build Year :N/A
# Views : 1.1K

# %%
print(len(property_face))
# Out:
# 266

# %%
house_dictionary.update({'title':title_val,'address':address_val,'price':price,'bedroom':bedroom,'bathroom':bathroom,'floor':floor,'parking':parking,'property_id':property_id,'property_face':property_face,'build_year':build_year,'views':views,'area_covered':area_covered,'road_access':road_access,'build_up_area':build_area,'posted':posted})

# %%
# house_dictionary={'title':[],'address':[],'price':[],'bedroom':[],'bathroom':[],'floor':[],'parking':[]}
# )
print(house_dictionary)
import pandas as pd
df_homedata = pd.DataFrame(house_dictionary)
df_homedata.to_csv('Dataset_house.csv')
# Out:
# {'title': ['Tokha House(Residential) : House For Sale In Tokha, Kathmandu', 'New House For Sale At Puspalal Chowk Biratnagar For Sale : House For Sale In DDC Chowk, Biratnagar', 'House For Sale In Tikathali, Lalitpur', 'COmmercial Property At Ringroad : House For Sale In Ekantakuna, Lalitpur', 'House For Sale In Tarkeshwor, Kathmandu', 'Bungalow For Sale In Gahanapokhari : House For Sale In Naxal, Kathmandu', 'House Sale In Chandragiri 7 : House For Sale In Chandragiri, Kathmandu', '22 Aana Amazing Bungalow For SALE At Bhaisepati, Lalitpur : House For Sale In Bhaisepati, Lalitpur', '13 Aana Amazing Bungalow For Sale , Bhaisepati : House For Sale In Bhaisepati, Lalitpur', 'House For Sale At Koteshwor. : House For Sale In Koteshwor, Kathmandu', 'House On Sale In Imadol : House For Sale In Imadol, Lalitpur', 'House On Sale In Tikathali : House For Sale In Tikathali, Lalitpur', 'House For Sale In Mahalaxmi Nagarpalika, Lalitpur', 'House For Sale In Mahalaxmi Nagarpalika, Lalitpur', 'Bungalow : House For Sale In Maharajgunj, Kathmandu', 'House For Sale In Thamel, Kathmandu', '4 Storey Residential Flat System House : House For Sale In Kalanki, Kathmandu', 'House For Sale : House For Sale In Chauthe, Pokhara', 'House For Sale Nakhu : House For Sale In Nakkhu, Lalitpur', 'House On Sale In Ranibari : House For Sale In Ranibari, Kathmandu', 'House On Sale In Imadol : House For Sale In Imadol, Lalitpur', 'House On Sale In Tikathali : House For Sale In Tikathali, Lalitpur', 'House For Sale In Mahalaxmi Nagarpalika, Lalitpur', 'House For Sale In Mahalaxmi Nagarpalika, Lalitpur', 'Bungalow : House For Sale In Maharajgunj, Kathmandu', 'House For Sale In Thamel, Kathmandu', '4 Storey Residential Flat System House : House For Sale In Kalanki, Kathmandu', 'House For Sale : House For Sale In Chauthe, Pokhara', 'House For Sale Nakhu : House For Sale In Nakkhu, Lalitpur', 'House On Sale In Ranibari : House For Sale In Ranibari, Kathmandu', 'House On Sale Sital Hight Imadol : House For Sale In Imadol, Lalitpur', 'House For Sale New House : House For Sale In Lekhnath, Pokhara', 'House On Sell In Imadol : House For Sale In Imadol, Lalitpur', 'House For Sale : House For Sale In Bafal, Kathmandu', 'RESIDENTIAL PLUS COMMERCIAL : House For Sale In Kupondole, Lalitpur', 'House For Sale Bhaisepati : House For Sale In Bhaisepati, Lalitpur', 'House For Sale At Hattiban Lalitpur : House For Sale In Hattiban, Lalitpur', 'Residential House For Sale : House For Sale In Sinamangal, Kathmandu', 'Residential Semi- Bungalow : House For Sale In Gurujudhara, Kathmandu', 'Imadole Inside 500m From Krishna Mandir : House For Sale In Imadol, Lalitpur', 'Jaga Kinda Ghar Sitai Ma : House For Sale In Ratnanagar, Chitwan', 'House For Sale In Gongabu Ganeshthan : House For Sale In Gongabu, Kathmandu', 'House On Sale On Hattigauda, Near Ganesh School : House For Sale In Budhanilkantha, Kathmandu', 'Bunglow For Sale At Tokha-6, Dhapasi, Kathmandu : House For Sale In Tokha, Kathmandu', 'House For Sale In Godawari, Lalitpur', 'Residential House For Sale At Khusibhu , Nayabazar : House For Sale In Khusibu, Kathmandu', 'Residential 2.5 Storey : House For Sale In Imadol, Lalitpur', 'House For Sale In Lekhnath, Pokhara : House For Sale In Lekhnath, Pokhara', 'Bodhi Homes : House For Sale In Bhairahawa, Rupandehi', 'Residential House On Sale Sipadol,Bhaktapur : House For Sale In Sipadol, Bhaktapur', 'House For Sale In Kapan, Kathmandu', 'Urgent Sale House At Naikap : House For Sale In Naikap, Kathmandu', 'Commercial House For Sale In Thamel With Attractive Rental Income : House For Sale In Thamel, Kathmandu', 'Box-Design : House For Sale In Tikathali, Lalitpur', 'RESIDENTIAL : House For Sale In Imadol, Lalitpur', 'HOUSE FOR SALE IN POKHARA : House For Sale In Pokhara, Pokhara', 'Brihat Community Living : House For Sale In Sitapaila, Kathmandu', 'RESIDENTIAL : House For Sale In Mahalaxmi Nagarpalika, Lalitpur', 'House For Sale In Kapan, Kathmandu', 'House For Sale Biratnagar : House For ...

# %%
df = pd.read_csv('Dataset_house.csv')
df.shape
# Out:
# (266, 16)

# %%
print(df.head())
# Out:
#    Unnamed: 0                                              title  \
# 0           0  New House For Sale At Puspalal Chowk Biratnaga...
# 1           1  New House For Sale At Puspalal Chowk Biratnaga...
# 2           2  New House For Sale At Puspalal Chowk Biratnaga...
# 3           3  New House For Sale At Puspalal Chowk Biratnaga...
# 4           4  New House For Sale At Puspalal Chowk Biratnaga...
#
#                                              address                   price  \
# 0  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
# 1  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
# 2  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
# 3  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
# 4  Puspalal Chowk, Biratnagar, DDC Chowk, Biratnagar  NPR. 90,00,000 Onwards
#
#    bedroom  bathroom  floor  parking property_id property_face  build_year  \
# 0        3         1      1        1     BN12539          East        2021
# 1        3         1      1        1     BN12539          East        2021
# 2        3         1      1        1     BN12539          East        2021
# 3        3         1      1        1     BN12539          East        2021
# 4        3         1      1        1     BN12539          East        2021
#
#    views area_covered          road_access build_up_area       posted
# 0    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
# 1    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
# 2    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
# 3    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
# 4    137      10 Dhur  20 Feet / Gravelled        7 Dhur  3 weeks ago
